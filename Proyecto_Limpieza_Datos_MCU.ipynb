# %% [markdown]
# <a href="https://colab.research.google.com/github/andyreinozaa/MCU_IMDb/blob/main/MCU_DF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
mcu_df = pd.read_csv('/content/MCU.csv')

# %%
mcu_df.head(20)
# Out:
#     Position      Const     Created    Modified  Description  \
# 0          1  tt0371746  2015-12-17  2015-12-17          NaN
# 1          2  tt0800080  2015-12-17  2015-12-17          NaN
# 2          3  tt1228705  2015-12-17  2015-12-17          NaN
# 3          4  tt0800369  2015-12-17  2015-12-17          NaN
# 4          5  tt0458339  2015-12-17  2015-12-17          NaN
# 5          6  tt0848228  2015-12-17  2015-12-17          NaN
# 6          7  tt1300854  2015-12-17  2015-12-17          NaN
# 7          8  tt1981115  2015-12-17  2015-12-17          NaN
# 8          9  tt1843866  2015-12-17  2015-12-17          NaN
# 9         10  tt2015381  2015-12-17  2015-12-17          NaN
# 10        11  tt2395427  2015-12-17  2015-12-17          NaN
# 11        12  tt0478970  2015-12-17  2015-12-17          NaN
# 12        13  tt3498820  2015-12-17  2015-12-17          NaN
# 13        14  tt1211837  2015-12-17  2015-12-17          NaN
# ...

# %%
mcu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Position        93 non-null     int64
#  1   Const           93 non-null     object
#  2   Created         93 non-null     object
#  3   Modified        93 non-null     object
#  4   Description     0 non-null      float64
#  5   Title           93 non-null     object
#  6   URL             93 non-null     object
#  7   Title Type      93 non-null     object
#  8   IMDb Rating     72 non-null     float64
#  9   Runtime (mins)  72 non-null     float64
#  10  Year            86 non-null     float64
#  11  Genres          92 non-null     object
#  12  Num Votes       72 non-null     float64
#  13  Release Date    86 non-null     object
#  14  Directors       51 non-null     object
# dtypes: float64(5), int64(1), object(9)
# memory usage: 11.0+ KB

# %%
mcu_df =mcu_df.drop('Const', axis=1)

# %%
mcu_df
# Out:
#     Position     Created    Modified  Description  \
# 0          1  2015-12-17  2015-12-17          NaN
# 1          2  2015-12-17  2015-12-17          NaN
# 2          3  2015-12-17  2015-12-17          NaN
# 3          4  2015-12-17  2015-12-17          NaN
# 4          5  2015-12-17  2015-12-17          NaN
# ..       ...         ...         ...          ...
# 88        89  2022-09-12  2022-09-12          NaN
# 89        90  2022-09-12  2022-09-12          NaN
# 90        91  2023-08-11  2023-08-11          NaN
# 91        92  2023-08-11  2023-08-11          NaN
# 92        93  2023-08-11  2023-08-11          NaN
#
#                                  Title  \
# 0                             Iron Man
# 1                  The Incredible Hulk
# 2                           Iron Man 2
# 3                                 Thor
# 4   Captain America: The First Avenger
# ..                                 ...
# 88        Untitled Marvel Nova Project
# ...

# %%
mcu_df =mcu_df.drop('Created', axis=1)
mcu_df =mcu_df.drop('Modified', axis=1)
mcu_df =mcu_df.drop('Description', axis=1)

# %%
mcu_df = mcu_df.rename(columns={'Position': 'Realeased_Order'})

# %%
mcu_df
# Out:
#     Realeased_Order                               Title  \
# 0                 1                            Iron Man
# 1                 2                 The Incredible Hulk
# 2                 3                          Iron Man 2
# 3                 4                                Thor
# 4                 5  Captain America: The First Avenger
# ..              ...                                 ...
# 88               89        Untitled Marvel Nova Project
# 89               90                      Marvel Zombies
# 90               91          Untitled Spider-Man Sequel
# 91               92                        Vision Quest
# 92               93                     The Daily Bugle
#
#                                        URL Title Type  IMDb Rating  \
# 0    https://www.imdb.com/title/tt0371746/      movie          7.9
# 1    https://www.imdb.com/title/tt0800080/      movie          6.6
# 2    https://www.imdb.com/title/tt1228705/      movie          6.9
# ...

# %%
mcu_df = mcu_df.rename(columns={'URL_imdb': 'URL_IMDb '})

# %%
mcu_df_realesed = mcu_df.dropna(axis=0)

# %%
mcu_df_realesed
# Out:
#     Realeased_Order                                              Title  \
# 0                 1                                           Iron Man
# 1                 2                                The Incredible Hulk
# 2                 3                                         Iron Man 2
# 3                 4                                               Thor
# 4                 5                 Captain America: The First Avenger
# 5                 6                                       The Avengers
# 6                 7                                     Iron Man Three
# 7                 8                               Thor: The Dark World
# 8                 9                Captain America: The Winter Soldier
# 9                10                            Guardians of the Galaxy
# 10               11                            Avengers: Age of Ultron
# 11               12                                            Ant-Man
# ...

# %%
mcu_df_realesed = mcu_df_realesed.rename(columns={'Num Votes': 'Votes in IMDb '})

# %%
mcu_df_realesed
# Out:
#     Realeased_Order                                              Title  \
# 0                 1                                           Iron Man
# 1                 2                                The Incredible Hulk
# 2                 3                                         Iron Man 2
# 3                 4                                               Thor
# 4                 5                 Captain America: The First Avenger
# 5                 6                                       The Avengers
# 6                 7                                     Iron Man Three
# 7                 8                               Thor: The Dark World
# 8                 9                Captain America: The Winter Soldier
# 9                10                            Guardians of the Galaxy
# 10               11                            Avengers: Age of Ultron
# 11               12                                            Ant-Man
# ...
